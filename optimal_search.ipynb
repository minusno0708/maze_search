# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
maze = np.loadtxt("sample_maze.txt")
plt.imshow(maze, cmap = "binary")

# %%
class cell():
    def __init__(self, place, cost):
        self.place = np.array([place[0], place[1]])
        self.cost = cost

# %%
class list():
    list = np.array([])
    
    def push(self, place, cost):
        for i in range(len(self.list)):
            if (self.list[i].place == place).all():
                if self.list[i].cost > cost:
                    self.list[i].cost = cost
                
                return -1
            
        self.list = np.append(self.list, cell(place, cost))
        
    def pop(self, x):
        if len(self.list) > x:
            temp = self.list[x]
            self.list = np.delete(self.list, x)
            return temp.place, temp.cost
        else:
            print(f"{x} is not exist")
            
            
    def sort(self):
        for i in range(len(self.list)-1):
            if(self.list[i].cost > self.list[i+1].cost):
                self.list[i], self.list[i+1] = self.list[i+1], self.list[i]
                
    def get(self, i):
        return cell(self.list[i].place, self.list[i].cost)
    
    def length(self):
        return len(self.list)
        
    def show(self):
        for i in range(len(self.list)):
            print(self.list[i].place, end=",")
            print(self.list[i].cost)

# %%
#隣接するセルの取得
def search(t):
    target = openlist.get(0)

    x = target.place[0]
    y = target.place[1]

    neighbor = np.array([
        [x+1, y], [x, y+1], [x-1, y], [x, y-1]
    ])

    for i in neighbor:
        if result_maze[i[0], i[1]] == 0:
            openlist.push(i, target.cost+1)
        
    searched_place, searched_cost = openlist.pop(t)
        
    closedlist.push(searched_place, searched_cost)
    
    openlist.sort()
    result_maze[x, y] = 2

# %%
# 初期設定
openlist = list()
closedlist = list()

result_maze = np.copy(maze)

openlist.push([1, 1], 0)

# 探索処理開始
while (result_maze[13, 13] == 0 and openlist.length() > 0):
    # 探索関数
    search(0)
    plt.imshow(result_maze)
    plt.show()
    plt.close()

# %%
closedlist.show()
# Out:
# [1 1],0
# [2 1],1
# [1 2],1
# [3 1],2
# [1 3],2
# [2 3],3
# [3 3],4
# [4 3],5
# [3 4],5
# [5 3],6
# [3 5],6
# [6 3],7
# [3 6],7
# [2 5],7
# [7 3],8
# [3 7],8
# [1 5],8
# [8 3],9
# [7 4],9
# [4 7],9
# [9 3],10
# [7 5],10
# [5 7],10
# [10  3],11
# [9 4],11
# [9 2],11
# [7 6],11
# [6 5],11
# [11  3],12
# [9 5],12
# [9 1],12
# [7 7],12
# [5 5],12
# [12  3],13
# [11  2],13
# [10  5],13
# [9 6],13
# [8 1],13
# [7 8],13
# [13  3],14
# [11  1],14
# [11  5],14
# [9 7],14
# [7 1],14
# [7 9],14
# [13  4],15
# [13  2],15
# [10  7],15
# [6 1],15
# [6 9],15
# [13  5],16
# [13  1],16
# [11  7],16
# [5 1],16
# [5 9],16
# [12  7],17
# [11  8],17
# [ 5 10],17
# [13  7],18
# [11  9],18
# [ 5 11],18
# [12  9],19
# [11 10],19
# [10  9],19
# [ 6 11],19
# [ 5 12],19
# [ 4 11],19
# [13  9],20
# [11 11],20
# [9 9],20
# [ 7 11],20
# [ 5 13],20
# [ 3 11],20
# [13 10],21
# [11 12],21
# [ 8 11],21
# [ 6 13],21
# [ 3 12],21
# [ 2 11],21
# [13 11],22
# [11 13],22
# [ 9 11],22
# [ 7 13],22
# [ 3 13],22
# [ 1 11],22
# [13 12],23
# [10 13],23
# [ 2 13],23
# [ 1 10],23
# [13 13],24
